# %%
import pandas as pd

# %%
fin = pd.read_csv("C:\Datahack\dirty data 2\jin.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\karti\AppData\Local\Temp\ipykernel_25244\3944336840.py:1: SyntaxWarning: invalid escape sequence '\D'
#   fin = pd.read_csv("C:\Datahack\dirty data 2\jin.csv")
# C:\Users\karti\AppData\Local\Temp\ipykernel_25244\3944336840.py:1: DtypeWarning: Columns (5,6,7,8,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   fin = pd.read_csv("C:\Datahack\dirty data 2\jin.csv")

# %%
fin2 = pd.read_csv("C:\Datahack\dirty data 2\jin2.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\karti\AppData\Local\Temp\ipykernel_25244\144492359.py:1: SyntaxWarning: invalid escape sequence '\D'
#   fin2 = pd.read_csv("C:\Datahack\dirty data 2\jin2.csv")

# %%
fin2.head()
# Out:
#           id callsign  flighthistory_id  latitude  longitude  \
# 0  108923851   SWA546         308536681      32.0     -106.5
# 1  108923851   SWA546         308536681      32.0     -106.5
# 2  108923851   SWA546         308536681      32.0     -106.5
# 3  108923851   SWA546         308536681      32.0     -106.5
# 4  108923851   SWA546         308536681      32.0     -106.5
#
#    asdiflightplan_id
# 0          114142575
# 1          114144129
# 2          114145255
# 3          114153741
# 4          114182481

# %%
fin['flighthistory_id'] = fin['id']

# %%
idk = pd.merge(fin, fin2, on='flighthistory_id', how='inner')
idk.head()
# Out:
#         id_x airline_icao_code  flight_number departure_airport_code  \
# 0  305968035               SNC           1327                    SFO
# 1  305913323               USC            608                    DAY
# 2  305923831               USC            801                    FWA
# 3  305923831               USC            801                    FWA
# 4  305923831               USC            801                    FWA
#
#   arrival_airport_code   scheduled_gate_departure actual_gate_departure  \
# 0                  SMF  2013-08-14 14:37:00+00:00                   NaN
# 1                  LUK  2013-08-14 20:30:00+00:00                   NaN
# 2                  STP  2013-08-14 23:00:00+00:00                   NaN
# 3                  STP  2013-08-14 23:00:00+00:00                   NaN
# 4                  STP  2013-08-14 23:00:00+00:00                   NaN
#
#       scheduled_gate_arrival actual_gate_arrival scheduled_runway_departure  \
# ...

# %%
idk.shape
# Out:
# (5251990, 26)

# %%
idk.head()
# Out:
#         id_x airline_icao_code  flight_number departure_airport_code  \
# 0  305968035               SNC           1327                    SFO
# 1  305913323               USC            608                    DAY
# 2  305923831               USC            801                    FWA
# 3  305923831               USC            801                    FWA
# 4  305923831               USC            801                    FWA
#
#   arrival_airport_code   scheduled_gate_departure actual_gate_departure  \
# 0                  SMF  2013-08-14 14:37:00+00:00                   NaN
# 1                  LUK  2013-08-14 20:30:00+00:00                   NaN
# 2                  STP  2013-08-14 23:00:00+00:00                   NaN
# 3                  STP  2013-08-14 23:00:00+00:00                   NaN
# 4                  STP  2013-08-14 23:00:00+00:00                   NaN
#
#       scheduled_gate_arrival actual_gate_arrival scheduled_runway_departure  \
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
idk.head()
# Out:
#         id_x airline_icao_code  flight_number departure_airport_code  \
# 0  305968035               SNC           1327                    SFO
# 1  305913323               USC            608                    DAY
# 2  305923831               USC            801                    FWA
# 3  305923831               USC            801                    FWA
# 4  305923831               USC            801                    FWA
#
#   arrival_airport_code   scheduled_gate_departure actual_gate_departure  \
# 0                  SMF  2013-08-14 14:37:00+00:00                   NaN
# 1                  LUK  2013-08-14 20:30:00+00:00                   NaN
# 2                  STP  2013-08-14 23:00:00+00:00                   NaN
# 3                  STP  2013-08-14 23:00:00+00:00                   NaN
# 4                  STP  2013-08-14 23:00:00+00:00                   NaN
#
#       scheduled_gate_arrival actual_gate_arrival scheduled_runway_departure  \
# ...

# %%
idk['creator_code'].value_counts()
# Out:
# creator_code
# I    4838016
# A     345095
# D      68879
# Name: count, dtype: int64

# %%
idk.drop(columns=['id_x','id_y','airline_icao_code','creator_code'],axis=1,inplace=True)

# %%
fin3 = pd.read_csv("C:\Datahack\dirty data 2\jin4.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\karti\AppData\Local\Temp\ipykernel_25244\481752556.py:1: SyntaxWarning: invalid escape sequence '\D'
#   fin3 = pd.read_csv("C:\Datahack\dirty data 2\jin4.csv")

# %%
fin3.head()
# Out:
#    Unnamed: 0   id  asdiflightplan_id ordinal  airway center    fix  \
# 0         208  300          114132888       1    EAU9    ZDC    J89
# 1         209  301          114132889       0  CRSON2    ZJX  SOONE
# 2         210  302          114132889       1  RACYR1    ZMA  ICBOD
# 3         211  303          114132890       O     J73    ZLA    OTK
# 4         212  304          114132890       1  FOOXX3    ZDV  HITTR
#
#     latitude  longitude  sector
# 0  39.783333 -75.050000  ZLCBOI
# 1  39.783333 -75.000000   ZLC31
# 2  39.783333 -74.966667   ZLC41
# 3  39.783333 -74.966667   ZLC42
# 4  39.783333 -74.950000  ZLCUTT

# %%
fin3.drop(columns=['Unnamed: 0','id','latitude','longitude'],axis=1,inplace=True)

# %%
idk2 = pd.merge(idk, fin3, on='asdiflightplan_id', how='inner')

# %%
idk2.to_csv('idk2.csv', index = False)

# %%
idk2.shape
# Out:
# (3664986, 27)

# %%
idk2.head()
# Out:
#    flight_number departure_airport_code arrival_airport_code  \
# 0           1327                    SFO                  SMF
# 1           1327                    SFO                  SMF
# 2           1327                    SFO                  SMF
# 3            801                    FWA                  STP
# 4            801                    FWA                  STP
#
#     scheduled_gate_departure actual_gate_departure     scheduled_gate_arrival  \
# 0  2013-08-14 14:37:00+00:00                   NaN  2013-08-14 15:40:00+00:00
# 1  2013-08-14 14:37:00+00:00                   NaN  2013-08-14 15:40:00+00:00
# 2  2013-08-14 14:37:00+00:00                   NaN  2013-08-14 15:40:00+00:00
# 3  2013-08-14 23:00:00+00:00                   NaN  2013-08-15 03:05:00+00:00
# 4  2013-08-14 23:00:00+00:00                   NaN  2013-08-15 03:05:00+00:00
#
#   actual_gate_arrival scheduled_runway_departure actual_runway_departure  \
# ...

# %%
idk2.head()
# Out:
#    flight_number departure_airport_code arrival_airport_code  \
# 0           1327                    SFO                  SMF
# 1           1327                    SFO                  SMF
# 2           1327                    SFO                  SMF
# 3            801                    FWA                  STP
# 4            801                    FWA                  STP
#
#     scheduled_gate_departure actual_gate_departure     scheduled_gate_arrival  \
# 0  2013-08-14 14:37:00+00:00                   NaN  2013-08-14 15:40:00+00:00
# 1  2013-08-14 14:37:00+00:00                   NaN  2013-08-14 15:40:00+00:00
# 2  2013-08-14 14:37:00+00:00                   NaN  2013-08-14 15:40:00+00:00
# 3  2013-08-14 23:00:00+00:00                   NaN  2013-08-15 03:05:00+00:00
# 4  2013-08-14 23:00:00+00:00                   NaN  2013-08-15 03:05:00+00:00
#
#   actual_gate_arrival scheduled_runway_departure actual_runway_departure  \
# ...

# %%
idk2.shape
# Out:
# (3664986, 27)

# %%
idk2.drop_duplicates
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 idk2.drop_duplicates
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\displayhook.py:268, in DisplayHook.__call__(self, result)
#     266 self.start_displayhook()
#     267 self.write_output_prompt()
# --> 268 format_dict, md_dict = self.compute_format_data(result)
#     269 self.update_user_ns(result)
#     270 self.fill_exec_result(result)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\displayhook.py:157, in DisplayHook.compute_format_data(self, result)
#     127 def compute_format_data(self, result):
#     128     """Compute format data of the object to be displayed.
#     129
#     130     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     155
#     156     """
# ...

# %%
idk2.shape
# Out:
# (3664986, 27)

# %%
null_percentages = idk2.isnull().mean() * 100

for column, percentage in null_percentages.items():
    print(f"{column}: {percentage}%")
# Out:
# flight_number: 0.0%
# departure_airport_code: 0.0%
# arrival_airport_code: 0.0%
# scheduled_gate_departure: 6.396231800066904%
# actual_gate_departure: 11.379470480924073%
# scheduled_gate_arrival: 6.39617722959924%
# actual_gate_arrival: 11.17412181110651%
# scheduled_runway_departure: 0.12583949843191763%
# actual_runway_departure: 0.7944914387121806%
# scheduled_runway_arrival: 0.14540301108926473%
# actual_runway_arrival: 0.4736170888510897%
# scheduled_air_time: 0.14540301108926473%
# scheduled_block_time: 6.396231800066904%
# departure_airport_timezone_offset: 0.0%
# arrival_airport_timezone_offset: 0.0%
# scheduled_aircraft_type: 8.044560061075268%
# icao_aircraft_type_actual: 1.2481084511646157%
# flighthistory_id: 0.0%
# callsign: 0.0%
# latitude: 0.0%
# longitude: 0.0%
# asdiflightplan_id: 0.0%
# ordinal: 0.0%
# airway: 0.0%
# center: 0.0%
# fix: 0.0%
# sector: 0.0%

# %%
idk2.columns
# Out:
# Index(['flight_number', 'departure_airport_code', 'arrival_airport_code',
#        'scheduled_gate_departure', 'actual_gate_departure',
#        'scheduled_gate_arrival', 'actual_gate_arrival',
#        'scheduled_runway_departure', 'actual_runway_departure',
#        'scheduled_runway_arrival', 'actual_runway_arrival',
#        'scheduled_air_time', 'scheduled_block_time',
#        'departure_airport_timezone_offset', 'arrival_airport_timezone_offset',
#        'scheduled_aircraft_type', 'icao_aircraft_type_actual',
#        'flighthistory_id', 'callsign', 'latitude', 'longitude',
#        'asdiflightplan_id', 'ordinal', 'airway', 'center', 'fix', 'sector'],
#       dtype='object')

# %%
idk2.drop('asdiflightplan_id',  axis=1, inplace = True)
idk2.drop('ordinal',  axis=1, inplace = True)

# %%
idk2.dropna(subset = ['scheduled_gate_departure', 'actual_gate_departure', 'scheduled_gate_arrival',  'actual_gate_arrival', 'scheduled_runway_departure', 'actual_runway_departure', 'scheduled_runway_arrival', 'actual_runway_arrival', 'scheduled_air_time', 'scheduled_block_time', 'scheduled_aircraft_type', 'icao_aircraft_type_actual'], inplace = True)

# %%
idk2.shape
# Out:
# (3141014, 25)

# %%
pd.set_option('display.max_rows', None)
idk2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3141014 entries, 17463 to 3664985
# Data columns (total 25 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   flight_number                      int64
#  1   departure_airport_code             object
#  2   arrival_airport_code               object
#  3   scheduled_gate_departure           object
#  4   actual_gate_departure              object
#  5   scheduled_gate_arrival             object
#  6   actual_gate_arrival                object
#  7   scheduled_runway_departure         object
#  8   actual_runway_departure            object
#  9   scheduled_runway_arrival           object
#  10  actual_runway_arrival              object
#  11  scheduled_air_time                 float64
#  12  scheduled_block_time               float64
#  13  departure_airport_timezone_offset  int64
#  14  arrival_airport_timezone_offset    int64
#  15  scheduled_aircraft_type            object
# ...

# %%
idk2.dtypes
# Out:
# flight_number                          int64
# departure_airport_code                object
# arrival_airport_code                  object
# scheduled_gate_departure              object
# actual_gate_departure                 object
# scheduled_gate_arrival                object
# actual_gate_arrival                   object
# scheduled_runway_departure            object
# actual_runway_departure               object
# scheduled_runway_arrival              object
# actual_runway_arrival                 object
# scheduled_air_time                   float64
# scheduled_block_time                 float64
# departure_airport_timezone_offset      int64
# arrival_airport_timezone_offset        int64
# scheduled_aircraft_type               object
# icao_aircraft_type_actual             object
# flighthistory_id                       int64
# callsign                              object
# latitude                             float64
# longitude                            float64
# ...

# %%
idk2[['callalpha', 'callnum']] = idk2['callsign'].str.extract(r'([A-Za-z]+)(\d+)')
